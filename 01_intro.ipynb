# %%
walletbalance = '$1500 worth of eth'
print (walletbalance)
# Out:
# $1500 worth of eth

# %%
a = 3
b = 5
c = 3+5

c
# Out:
# 8

# %%
btc = 120000
if btc >= 120000:
    print('bullish')
# Out:
# bullish

# %%
"hello world"
# Out:
# 'hello world'

# %%
crypto_wallet ='kucoin'
print(f'hold 1 btc in my {crypto_wallet}!')
# Out:
# hold 1 btc in my kucoin!
